# %%
class Person:
    def __init__(self,name,firstname):
        self.__name = name
        self.__firstname = firstname
    
    def sePresenter(self):
        print(f"I am {self.__firstname} {self.__name}")
    
    def get_name(self):
        return self.__name
    
    def get_firstname(self):
        return self.__firstname
    
    def set_name(self, name):
        self.__name = name
    
    def set_firstname(self, firstname):
        self.__firstname = firstname

# %%
class Book():
    def __init__(self,title,author):
        self.__title = title
        self.__author = author
    
    def __str__(self):
        return book.__title
    
    def get_title(self):
        return self.__title
    
    def get_author(self):
        return self.__author

class Author(Person):
    def __init__(self,name,firstname):
        Person.__init__(self,name,firstname)
        self.__list_of_books = []
    
    def get_name(self):
        return self.__firstname + ' ' + self.__name
    
    def listerWork(self):
        for book in self.__list_of_books:
            print(book.get_title())
    
    def writeABook(self,title):
        book = Book(title,self)
        self.__list_of_books.append(book)
    
    def get_title(self):
        titles = []
        for book in self.__list_of_books:
            titles.append(book.get_title())
        return titles

# %%
class Library():
    def __init__(self):
        self.books = {}
    
    def buyBook(self,author,title,number):
        if title in author.get_title():
            if title in self.books.keys():
                self.books[title] += number
            else:
                self.books[title] = number
            
    def inventory(self):
        print('Inventory of the library \n')
        for book, number in self.books.items():
            print(f'{book} -> {number}')
    
    def rent(self,client,title):
        if self.books[title] > 0:
            self.books[title] -= 1
            client.add_book(title)
    
    def renderBooks(self,client):
        for title in client.get_books():
            self.books[title] += 1
            client.empty_book()

class Client(Person):
    def __init__(self,name,firstname):
        Person.__init__(self,name,firstname)
    
    books = []
    
    def add_book(self,title):
        self.books.append(title)
    
    def get_books(self):
        return self.books
    
    def empty_book(self):
        self.books = []
    
    def inventory(self):
        for book in self.books:
            print(book)
